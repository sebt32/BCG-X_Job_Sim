# %% [markdown]
# ## The chatbot only accepts these predefined queries
# \
# What is the total revenue? \
# What is the Net Income? \
# What is the cash flow from operations growth(%)? \
# What is the year by year average assets growth rate(%)? \
# What is the year by year average liabilities growth rate(%)? \
# \
# Copy one of these when asked for query

# %%
import pandas as pd

# %%
df = pd.read_csv('data_report.csv')
df_2 = pd.read_csv('summary_report.csv')

# %%
df
# Out:
#    Year  Total Revenue  Net Income  Total Assets  Total Liabilities  \
# 0  2021         365817       94680        351002             287912
# 1  2022         394328       99803        352755             302083
# 2  2023         383285       96995        352583             290437
# 3  2021         168088       61271        333779             191791
# 4  2022         198270       72738        364840             198298
# 5  2023         211915       72361        411976             205753
# 6  2021          53823        5644         62131              30548
# 7  2022          81462       12587         82338              36440
# 8  2023          96773       14974        106618              43009
#
#    Cash Flow from Operating Activities    Company  Revenue Growth (%)  \
# 0                               104038      Apple            0.000000
# 1                               122151      Apple            7.793788
# 2                               110543      Apple           -2.800461
# ...

# %%
df_2
# Out:
#      Company  Revenue Growth (%)  Net Income Growth (%)  Assets Growth (%)  \
# 0      Apple            2.496664               1.298657           0.225334
# 1  Microsoft           12.419050               9.098459          11.112747
# 2      Tesla           35.073460              70.989801          31.005712
#
#    Liabilities Growth (%)  Cash Flow from Operations Growth(%)
# 0                0.533379                             3.953496
# 1                3.576124                             7.194844
# 2               18.657286                             9.049037

# %%
# %run chatbot.py
# Out:
# ----------------------------------------------------------------------------
#
# Enter 'Hi' to start the chatbot session; type 'exit' to quit: hi
#
# Hello! Welcome to the Financial Chatbot.
#
# I can help you with your financial queries.
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name: microsoft
#
# The data for the fiscal years 2023, 2022, and 2021 is currently available.
# Enter the fiscal year for the selected company: 2022
#
# Please enter your query
# What is the year by year average liabilities growth rate(%)?
# The Year by Year Average Liabilities Growth Rate(%) for Microsoft is 3.58%
# ----------------------------------------------------------------------------
#
# Enter 'Hi' to start the chatbot session; type 'exit' to quit: exit

# %%
# %run chatbot.py
# Out:
# ----------------------------------------------------------------------------
#
# Enter 'Hi' to start the chatbot session; type 'exit' to quit: e
# Enter 'Hi' properly by starting the chatbot session again.

# %%
# %run chatbot.py
# Out:
# ----------------------------------------------------------------------------
#
# Enter 'Hi' to start the chatbot session; type 'exit' to quit: hi
#
# Hello! Welcome to the Financial Chatbot.
#
# I can help you with your financial queries.
# Please select the company name from below: -
#
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter company name: tesla
#
# The data for the fiscal years 2023, 2022, and 2021 is currently available.
# Enter the fiscal year for the selected company: 2023
#
# Please enter your query
# What is the Net Income?
# The Net Income for Tesla for fiscal year 2023 is $ 14974
# ----------------------------------------------------------------------------
#
# Enter 'Hi' to start the chatbot session; type 'exit' to quit: exit
